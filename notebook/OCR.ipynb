# %%
import matplotlib.pyplot as plt
import cv2
from IPython.display import Image
import easyocr

# %%
Image(r"C:\Users\tanji\Desktop\myPW\end to endprojects\AI-CNN\car-plate/plates/scaned_img_1.jpg")

# %%
reader=easyocr.Reader(['en'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
output=reader.readtext(r"C:\Users\tanji\Desktop\myPW\end to endprojects\AI-CNN\car-plate/plates/scaned_img_1.jpg")

# %%
output
# Out:
# [([[46, 42], [325, 42], [325, 127], [46, 127]], 'A 111AA', 0.6133893903222155),
#  ([[362, 100], [408, 100], [408, 124], [362, 124]],
#   'RUSi',
#   0.1408979445695877),
#  ([[368, 54], [428, 54], [428, 104], [368, 104]], '77', 0.47568880273996683)]
